# %% [raw]
# 1、https://zhuanlan.zhihu.com/p/103754069?utm_source=wechat_timeline 推荐系统之用户画像
# 2、http://www.woshipm.com/user-research/3780886.html
# 3、https://www.bilibili.com/video/av243681112/
# 4、https://baijiahao.baidu.com/s?id=1659585422481389602&wfr=spider&for=pc 基于知识图谱的推荐系统
# 5、https://zhuanlan.zhihu.com/p/153317362 基于知识图谱的推荐系统综述
# 6、https://zhuanlan.zhihu.com/p/59762355 推荐系统结合知识图谱简单总结  ！！！！
# 7、https://www.jianshu.com/p/0a79ccd2ef8d 知识图谱与推荐系统    ！！！！！
#   知识图谱一般不用于基于特征的推荐系统，一般用于基于路径的推荐
#
# 8、https://blog.csdn.net/zandaoguang/article/details/107948017 ranking loss 推荐系统中 用户画像编码 与 商品编码 的 loss
#   ranking loss的目的是去预测输入样本之间的相对距离。这个任务经常也被称之为度量学习
#
# 9、https://zhuanlan.zhihu.com/p/157636795  图谱推荐综述：Knowledge Graph-Based Recommender Systems  ！！！！！！！！
# 10、https://blog.csdn.net/qq_33589510/article/details/88058396 基于协同过滤的推荐系统
# 11、https://www.pianshen.com/article/53851110894/ 斯坦福大学机器学习笔记——推荐系统（协同过滤、低秩分解、推荐系统） ！！！！！！
# 12、 https://www.pianshen.com/article/8178454754/
#    https://zhuanlan.zhihu.com/p/27768663  详解个性化推荐五大最常用算法
#    https://lusongsong.com/info/post/9829.html  今日头条推荐算法原理全文详解
#    https://mp.weixin.qq.com/s/5v8dMKWySulVAFfs9p-nRw
#
#    https://zhuanlan.zhihu.com/p/23036112
#    https://blog.csdn.net/u013714645/article/details/97899342?utm_medium=distribute.pc_relevant.none-task-blog-BlogCommendFromMachineLearnPai2-2.control&dist_request_id=&depth_1-utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromMachineLearnPai2-2.control Yotubu 推荐算法
# https://cloud.tencent.com/developer/news/384224   Yotubu 推荐算法
# https://blog.csdn.net/weixin_40901056/article/details/88568344?utm_medium=distribute.pc_relevant.none-task-blog-baidujs_baidulandingword-0&spm=1001.2101.3001.4242  work2vec 负采样 （转化成2分类， 损失=正样板损失（等于正样本） + 负样本损失（等于负样本） ）
#     推荐算法
# 推荐算法 baidu
#
# 13、https://blog.csdn.net/elaine_bao/article/details/52012537  知识图谱表示
# 14、开源推荐系统
#     https://www.cnblogs.com/jpfss/p/11798104.html
#     http://muricoca.github.io/crab/
#    https://github.com/ocelma/python-recsys
#    https://github.com/rootid/recommender_system
#    https://apple.github.io/turicreate/docs/userguide/recommender/
#
# 15、https://zhuanlan.zhihu.com/p/219898749?utm_source=wechat_timeline
#     https://www.cnblogs.com/z1141000271/p/11378631.html   推荐系统实践
#
# 16、https://zhuanlan.zhihu.com/p/219898749?utm_source=wechat_timeline  推荐引擎的架构
#
# 17、https://github.com/zhaozhiyong19890102/Recommender-System 汇总信息
#
# 18、https://www.pianshen.com/article/6158928903/  吴恩达机器学习之推荐系统
# 19、https://blog.csdn.net/liheng301/article/details/104949467 推荐系统之召回策略浅析
#    https://zhuanlan.zhihu.com/p/58160982
#    https://baijiahao.baidu.com/s?id=1627686136880502710&wfr=spider&for=pc
# 20、https://zhuanlan.zhihu.com/p/259985388 从零开始了解推荐系统全貌
# 21、https://blog.csdn.net/liuchenbaidu/article/details/104944152
#    https://www.cnblogs.com/ljygoodgoodstudydaydayup/p/10519253.html
#    最近邻搜索和近似最近邻搜索（NN和ANN）和库
#
# 22、https://www.pythonheidong.com/blog/article/430208/8f38eeab1a7ddfd17bf6/  大规模向量相似度计算(一)——hnswlib的基本使用示例
#
# 23、https://blog.csdn.net/friyal/article/details/83589232
#    https://www.inf.unibz.it/~ricci/ISR/papers/p293-davidson.pdf
#    YouTube推荐系统
#
# 24、https://buildingrecommenders.wordpress.com/2015/11/18/overview-of-recommender-algorithms-part-2/   ！！！！！
#    https://buildingrecommenders.wordpress.com/2015/11/18/recommender-systems-in-netflix/
#    https://blog.csdn.net/qq_19446965/article/details/82079367?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-9.control&dist_request_id=&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-9.control   推荐系统中的矩阵分解总结
#
# 25、召回
#    https://blog.csdn.net/everyonetimeismoney/article/details/113249478?utm_medium=distribute.pc_relevant.none-task-blog-baidujs_baidulandingword-1&spm=1001.2101.3001.4242  内容召回策略实现 & 实现在线召回策略及模型召回策略
#   https://blog.csdn.net/qq_34219959/article/details/104495432?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-2.control&dist_request_id=1330147.33308.16181952226742503&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-2.control 推荐算法总结（召回+排序+工程化）
#
# 26、https://zhuanlan.zhihu.com/p/52169807  重读Youtube深度学习推荐系统论文
#
# 27、https://blog.csdn.net/zhang2010hao/article/details/80612747?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-2.control&dist_request_id=1331303.8144.16182787840300525&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-2.control
#
# https://nbviewer.jupyter.org/github/Wxj-0920/cda-/blob/master/04.%E5%9F%BA%E4%BA%8E%E8%81%9A%E7%B1%BB%E7%9A%84%E4%B8%AA%E6%80%A7%E5%8C%96%E6%8E%A8%E8%8D%90.ipynb  ！！！
#
# https://nbviewer.jupyter.org/github/Wxj-0920/cda-/blob/master/%E7%94%B5%E5%95%86%E7%8E%A9%E5%85%B7%E5%85%AC%E5%8F%B8%E6%95%B0%E6%8D%AE%E6%A1%88%E4%BE%8B.ipynb   ！！！
#
# https://nbviewer.jupyter.org/github/Wxj-0920/cda-/tree/master/
#
# https://www.jianshu.com/p/4eafa11db30d  推荐系统第二周itemCF和userCF的实现
#
# 实例  ！！！
#
# 28、https://zhuanlan.zhihu.com/p/126282487 DeepMatch: 用于推荐&广告的深度召回匹配算法库
#
# 29、https://aaronice.gitbook.io/system-design/system-design-problems/recommendation-system Design Recommendation System
#
# 推荐系统的一个例子数据
#
# 30、https://zhuanlan.zhihu.com/p/121626317   ！！！
# https://github.com/search?q=recommender-system
#
# 31、https://zhuanlan.zhihu.com/p/50426292 FM  Factorization Machine 因子分解机
#    https://blog.csdn.net/itplus/article/details/40534885
#    https://segmentfault.com/a/1190000014799038  特征组合&特征交叉 (Feature Crosses)
#
# 33、https://www.pianshen.com/article/5893326796/ 《Deep Neural Networks for YouTube Recommendations》论文总结 ！！！
#    https://proceedings.neurips.cc/paper/2004/file/1102a326d5f7c9e04fc3c89d0ede88c9-Paper.pdf  临近相似， LSH ！！！！针对大规模分类
#    https://blog.csdn.net/zchang81/article/details/79034374 ！！！！
# 32、https://blog.csdn.net/icvpr/article/details/12342159  LSH ！！！！， 对数据包括用户、物品建索引 可支持相近查找。
# 33、https://www.cnblogs.com/yinzm/p/11827905.html 特征工程
#    https://www.cnblogs.com/yinzm/p/11619829.html
#    https://github.com/loserChen/TensorFlow-In-Practice
#    https://blog.csdn.net/w55100/article/details/90295932  pytorch deepFM
#    https://blog.csdn.net/weixin_28981373/article/details/112350090?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-1.control&dist_request_id=&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-1.control
#    https://blog.csdn.net/springtostring/article/details/108157070
#    https://blog.csdn.net/weixin_29745919/article/details/112292825?utm_medium=distribute.pc_relevant.none-task-blog-baidujs_title-1&spm=1001.2101.3001.4242 ！！！！！！
#    https://blog.csdn.net/g11d111/article/details/77430095?utm_medium=distribute.pc_feed_404.none-task-blog-2~default~BlogCommendFromMachineLearnPai2~default-4.nonecase&dist_request_id=1331633.7722.16184596860552253&depth_1-utm_source=distribute.pc_feed_404.none-task-blog-2~default~BlogCommendFromMachineLearnPai2~default-4.nonecas
#
#
# 34、https://www.zhihu.com/question/29316149   ！！！！！
#
#    特征工程
#
#
# 35、https://zhuanlan.zhihu.com/p/45167021 [Graph Embedding]阿里超大规模商品Embedding策略EGES
#    https://zhuanlan.zhihu.com/p/133870768
#
# 36、https://zhuanlan.zhihu.com/p/343174108 FM：推荐算法中的瑞士军刀
#    https://zhuanlan.zhihu.com/p/58160982  推荐系统召回四模型之：全能的FM模型
#    https://blog.csdn.net/tMb8Z9Vdm66wH68VX1/article/details/79091671?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-3.control&dist_request_id=1331973.6564.16185382717881981&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-3.control  Python FM实现
#    https://zhuanlan.zhihu.com/p/100019681 ！！！
#    https://zhuanlan.zhihu.com/p/100779249 多兴趣网络
#    https://zhuanlan.zhihu.com/p/141517705 推荐系统中稀疏特征Embedding的优化表示方法

# %% [raw]
# 开源：
# https://github.com/grahamjenson/list_of_recommender_systems
# https://github.com/search?q=recommender-system
# 1、https://github.com/kasravnd/Rexy
# 2、https://lenskit.org/
# 3、http://surpriselib.com/
# 4、https://github.com/maciejkula/spotlight
# 5、https://github.com/PreferredAI/cornac
# 6、https://github.com/microsoft/recommenders
# 7、https://github.com/DeepGraphLearning/RecommenderSystems
# 8、https://github.com/apachecn/RecommenderSystems ！！！
# 9、https://apple.github.io/turicreate/docs/userguide/recommender/
# 10、https://zhuanlan.zhihu.com/p/269635363?utm_source=wechat_session  https://github.com/ChuanyuXue/Recommender-Systems-Competition-TopSolutions
# 11、https://developer.51cto.com/art/201911/606905.htm
# 12、https://xw.qq.com/cmsid/20201105A0EKA800

# %% [markdown]
# how to design a industrial level recommendation system
# how to design a large data recommendation system
# recommender system  data sparsity
#
# 1、https://towardsdatascience.com/recommendation-system-series-part-1-an-executive-guide-to-building-recommendation-system-608f83e2630a  ！！！！！
#
# 2、https://medium.com/@pankaj.iitkgp08/guide-for-developing-an-industrial-level-recommender-system-quickly-c4c92bf0e04c
#
# 3、https://marutitech.com/recommendation-engine-benefits/
#
# 4、https://www.alibabacloud.com/blog/recommender-system-ranking-algorithms-and-training-architectures_596643
#
# 5、https://www.alibabacloud.com/blog/basic-concepts-and-architecture-of-a-recommender-system_596642
#
# 6、https://medium.com/swlh/how-to-build-simple-recommender-systems-in-python-647e5bcd78bd
#
# 7、https://www.hindawi.com/journals/complexity/2020/6619249/
#
# 8、https://iopscience.iop.org/article/10.1088/1742-6596/1477/3/032024/pdf
#
# 9、https://customerthink.com/explained-working-and-advantages-of-a-recommendation-engine/
#
# 10、https://cloud.google.com/solutions/recommendations-using-machine-learning-on-compute-engine  ！！！！
#
# 11、https://blog.csdn.net/weixin_42229056/article/details/82966477   ！！！！
#
# 12 、https://zhuanlan.zhihu.com/p/157834679
#
# 13、https://iopscience.iop.org/article/10.1088/1742-6596/1477/3/032024/pdf  Book Recommendation System Development Using User-Based Collaborative Filtering

# %% [raw]
# 推荐系统的目的旨在为 user (用户) 推荐一个（或一系列）未观测的 item (物品，电影，新闻等)。基本步骤如下：
# 1） 学习 user 和 item 的向量表示 和
# 2） 根据 1 中的 user 和 item 向量表示，计算表示 user 对 item 的偏好得分，得分函数可以采用內积、DNN等。
# 3） 基于 2 中计算的得分，进行排序推荐。
#
#
# 推荐系统主要包含以下三种方法：
#
#  1） Collaborative Filtering (CF): 基于协同过滤的推荐系统，协同过滤算法是从相似度度量出发，考虑 user 或者 item 之间的相似度进行相关推荐，它比较常用的两种方法是基于内存（memory-based）和基于模型（model-based）的两种方法。
#  2） Content-based Filtering (CB)：基于内容的推荐系统，与基于协同过滤从全局 user 和 item 的交互数据中学习他们的向量表示相比，基于内容的推荐方法从 item 的内容中学习 user 和 item 的表示。它认为 user 可能对与他们过去交互过的 item 中相似的 item 感兴趣。
# 3）  Hybrid Method：混合推荐系统，CF 方法容易遇到冷启动或者交互矩阵数据稀疏的问题，而混合推荐系统可以利用基于内容的推荐系统中的 user 和 item 信息来缓解这一问题。混合推荐系统通过将 user 和 item 的内容信息，即用户辅助信息和物品辅助信息整合到 CF 的框架中，可以获得更好的推荐性能。
#
#
#
# 推荐系统的推荐任务也非常广泛，有：
# 新加入物品推荐给用户。 广告推荐给用户。 推荐不同种类物品。 关联推荐。 标签推荐。
# 如果都考虑上述特征和任务，则系统将会非常复杂，并且很难通过配置文件来配置不同特征和任务。因此。推荐系统需要有多个推荐引擎组成，每个推荐引擎负责某一类特征和任务，最终推荐系统的任务就是将推荐引擎的结果按照一定权重或优先级合并、排序。
