# %% [raw]
# https://github.com/microsoft/recommenders  学习实例
# https://phoenixnap.com/kb/install-spark-on-windows-10
#
# https://www.pythonheidong.com/blog/article/445549/cb1309bc304a0ab5e87f/  sklearn FeatureHasher中的哈希技巧
#
# https://blog.csdn.net/laolu1573/article/details/79410187  特征hash
# https://blog.csdn.net/xzx1232010/article/details/83026276 特征hash
# https://scikit-learn.org.cn/view/122.html  !!!!!
# https://scikit-learn.org/stable/modules/feature_extraction.html
#
# https://github.com/lyst/lightfm
# https://making.lyst.com/lightfm/docs/home.html
# https://github.com/microsoft/recommenders
#
# https://www.jianshu.com/p/9c40b8dc60bf 数据特征处理之特征哈希
# https://scikit-learn.org/stable/modules/manifold.html#manifold  data embeding ！！！！
#
# http://infolab.stanford.edu/~ullman/mmds/ch3.pdf Finding Similar Items
# https://zhuanlan.zhihu.com/p/45497946 MinHash
# https://github.com/ekzhu/datasketch
# https://blog.csdn.net/guoziqing506/article/details/53019049
# https://github.com/usc-isi-i2/dig-lsh-clustering
# https://baijiahao.baidu.com/s?id=1677971182466878776&wfr=spider&for=pc
# https://www.bbsmax.com/A/gGdXLOOYd4/  几种实现one-hot编码的方式
# https://dpengwang.blog.csdn.net/article/details/84838688 pandas 中对特征进行硬编码和onehot编码
# https://blog.csdn.net/sinat_26917383/article/details/70285678  LSH Python实现
# https://cloud.tencent.com/developer/article/1010901 LSH实现
# https://zhuanlan.zhihu.com/p/46164294 大规模数据的相似度计算：LSH算法
# https://blog.csdn.net/liuzonghao88/article/details/86322912
#
# https://blog.csdn.net/ZhikangFu/article/details/46683593?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-11.control&dist_request_id=1331988.2033.16187435646812225&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-11.control
#
# https://blog.csdn.net/qysh123/article/details/113754991?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Edefault-8.control&dist_request_id=1331989.1940.16187447580681771&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Edefault-8.control
# https://github.com/usc-isi-i2/dig-lsh-clustering
# http://mcg.nju.edu.cn/publication/2014/icimcs14-xuxy.pdf
# https://github.com/FALCONN-LIB/FALCONN/wiki/LSH-Primer !!!
# http://proceedings.mlr.press/v80/bhaskara18a/bhaskara18a.pdf
# bing LSH cluster
# bing minHash cluster
# https://zhuanlan.zhihu.com/p/29002395  用户画像聚类
# https://zhuanlan.zhihu.com/p/150287629
# https://zhuanlan.zhihu.com/p/42883870
# https://zhuanlan.zhihu.com/p/113213283
# https://blog.csdn.net/q18729096963/article/details/103895601?utm_medium=distribute.pc_relevant.none-task-blog-baidujs_title-0&spm=1001.2101.3001.4242 ！！！！！
# https://www.cnblogs.com/sddai/p/6110704.html ！！！！
# https://www.cnblogs.com/shipengzhi/articles/2826209.html !!!!!
# http://www.doc88.com/p-3397953228687.html 一种改进的LSH_MinHash协同过滤算法 - 道客巴巴  !!!!!!
# https://pypi.org/project/LSH-LINK/  LSH Cluster
# https://fdocuments.in/reader/full/fast-agglomerative-hierarchical-clustering-algorithm-using-locality-sensitive！！！！
#
# https://blog.csdn.net/qq_27825451/article/details/94436488 基于sklearn的聚类算法的聚类效果指标
#
# http://mlwiki.org/index.php/K-Means_LSH
# https://inquest.net/blog/2019/02/28/Ex-Machina-Family-Matters ！！！！！
#
# https://github.com/Brian1357/STA663-Project-LSHLink  !!!!!!!!!!!
# https://github.com/armenabnousi/minhash_clustering  ！！！
# https://inquest.net/blog/2019/02/28/Ex-Machina-Family-Matters ！！！！
# https://blog.csdn.net/weixin_40901056/article/details/97376614 ！！！！
# https://datascience.stackexchange.com/questions/46950/are-there-algorithms-for-clustering-objects-with-pairwise-distances-without-com ！！！！！
#
#
# 1.《Google News Personalization: Scalable Online Collaborative Filtering》根据用户的历史点击数据，进行新闻推荐；采用最小哈希聚类的协同过滤算法
#
# https://blog.csdn.net/theonlytank2011/article/details/9497725?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-1.control&dist_request_id=&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromMachineLearnPai2%7Edefault-1.control
#
# https://blog.csdn.net/sinat_26917383/article/details/70243066  python实现局部敏感随机投影森林
# 作者：采石工
# 链接：https://www.zhihu.com/question/284721669/answer/1267604358
# 来源：知乎
# 著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。
#
# 暂时想到一个简单暴力的方法:1) 提取待检索电影的每一帧图像的局部敏感哈希 (Locality Sensitive Hashing; LSH) 特征,
# 并保存下来, 不妨称为库 (gallery). LSH 特征可以用整型来表示, 一般是64位的. 两张图像的 LSH 特征的 Hamming 距离,
# 可以表征图像之间的差异. 而 Hamming 距离在编程语言中可以很高效的实现 (只需计算两个整型的异或运算的popcnt).
# 常见的图像 LSH 特征有 pHash, aHash, dHash 等.2) 来了一张查询图像 (query), 也计算它的 LSH 特征. 然后与预先
# 保存下来的库中的每个 LSH 特征都计算 Hamming 距离, 返回库中与查询图像 LSH 特征距离最小 (或距离小于指定阈
# 值) 的一个或多个 LSH 特征, 它们的标签 (即属于哪部电影) 我们也是知道的, 然后统计每个电影标签出现的频次, 哪部电
# 影的标签出现的最多即认为查询图像来自于哪部电影 (即最近邻分类器 KNN 的思想). 综上, 要完成的你的需求, 可能需要
# 深入了解一下: 图像检索, 视频检索, 局部敏感哈希, (近似)最近邻搜索等.
#
#
# 聚类算法：
# 1、https://blog.csdn.net/zcmlimi/article/details/87929070 Agglomerative Hierarchical Clustering-聚合层次聚类
# ！！！ 2、https://scikit-learn.org/stable/modules/generated/sklearn.cluster.FeatureAgglomeration.html#sklearn.cluster.FeatureAgglomeration
# ！！！3、https://blog.csdn.net/huacha__/article/details/81094891 DBSCAN密度聚类算法 包括怎么评估
# 4、https://zhuanlan.zhihu.com/p/29848130 BIRCH聚类算法

# %% [raw]
# LSH
#
# https://pypi.org/project/LocalitySensitiveHashing/
# https://github.com/dougian/lsh
# https://github.com/mattilyra/LSH !
# https://stackoverflow.com/questions/53348824/faster-implementation-of-lsh-and-or !!!!
# https://www.learndatasci.com/tutorials/building-recommendation-engine-locality-sensitive-hashing-lsh-python/
# https://blog.csdn.net/sinat_26917383/article/details/70332325
# https://cloud.tencent.com/developer/article/1010968 LSH︱python实现局部敏感随机投影森林 聚类
# https://github.com/dougian/lsh
# https://github.com/justinnbt/SnaPy
# https://blog.csdn.net/IOT_victor/article/details/104044453
# https://pypi.org/project/LSH-LINK/  LSH Cluster
# https://blog.csdn.net/w5688414/article/details/108181415  minHash implement
# https://blog.csdn.net/ChenVast/article/details/82992206?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Edefault-5.control&dist_request_id=&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Edefault-5.control  使用Python中的局部敏感哈希（LSH）构建推荐引擎
#
# https://github.com/rahularora/MinHash
# https://github.com/go2starr/lshhdc
# https://github.com/1e0ng/simhash
# https://www.itdaan.com/tw/3908bf232c82 LSH︱python實現局部敏感哈希——LSHash（二）
#
# https://www.cnpython.com/qa/55057 minhash简单实现
# https://blog.csdn.net/w5688414/article/details/108181415 minhash简单实现
# https://blog.csdn.net/weixin_30443075/article/details/95429386?utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Edefault-7.control&dist_request_id=&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Edefault-7.control minhash简单实现
# https://wenku.baidu.com/view/089e85c42cc58bd63186bdfc.html  minhash原理
#
# https://docs.python.org/3/library/hashlib.html  包括多个HASH
# https://www.cnblogs.com/bonelee/p/10955307.html  python spark minHASH
