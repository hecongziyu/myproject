# %% [raw]
# 1、https://towardsdatascience.com/aifortrading-2edd6fac689d
# 2、https://www.zhihu.com/question/19714540  傅里叶变换
# 3、https://www.cnblogs.com/h2zZhou/p/8405717.html 深入浅出的讲解傅里叶变换（真正的通俗易懂）
# 4、https://blog.csdn.net/GarfieldEr007/article/details/51685256?depth_1-utm_source=distribute.pc_relevant.none-task&utm_source=distribute.pc_relevant.none-task 傅里叶变换应用
# 5、https://blog.csdn.net/qq_27825451/article/details/88553441 使用python（scipy和numpy）实现快速傅里叶变换（FFT）最详细教程

# %%
from matplotlib import pyplot as plt
import numpy as np
from lib.data import *
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
#  numpy fft 快速傅里叶变换FFT

ft = IncomeFeature(code='002261')
ft.add_feature()

sdata = ft.get_data()
# print(sdata.tail(30))

plt.figure(figsize=(14, 7), dpi=100)
close_fft = np.fft.fft(np.asarray(sdata.Close.tolist()))
fft_df = pd.DataFrame({'fft':close_fft},index=sdata.index)
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))
# print(fft_df.tail(10))
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3,6,9,]:
    fft_list_m10= np.copy(fft_list); 
    fft_list_m10[num_:-num_]=0
    ifft_df = pd.DataFrame({'ifft':np.fft.ifft(fft_list_m10)},index=sdata.index)
#     print(ifft_df.tail(10))
#     plt.plot(np.fft.ifft(fft_list_m10), label='{} components'.format(num_))
# plt.plot(sdata.Close.tolist(), label='real')
# plt.legend()


# print(sdata.head(10))
# Out:
# d:\project_tw\twedu\venv37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# d:\project_tw\twedu\venv37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# d:\project_tw\twedu\venv37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
from matplotlib import pyplot as plt
import numpy as np
from lib.data import *
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
#  numpy fft 快速傅里叶变换FFT

ft = CloseAndVolumeDiffFeature(code='002261')
ft.add_feature()
sdata = ft.get_data()
sdata[sdata.DCC>5] = 0
sdata[sdata.DCC<-5] = 0

plt.figure(figsize=(14, 7), dpi=100)
close_fft = np.fft.fft(np.asarray(sdata.DCC.tolist()))
fft_df = pd.DataFrame({'fft':close_fft},index=sdata.index)
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))
fft_list = np.asarray(fft_df['fft'].tolist())
plt.plot(sdata.DCC.tolist()[-300:], label='real')
for num_ in [9,20,100,]:
    fft_list_m10= np.copy(fft_list); 
    fft_list_m10[num_:-num_]=0
    ifft_df = pd.DataFrame({'ifft':np.fft.ifft(fft_list_m10)},index=sdata.index)
    plt.plot(np.fft.ifft(fft_list_m10)[-300:], label='{} components'.format(num_))

plt.legend()


# print(sdata.head(10))
# Out:
# d:\project_tw\twedu\venv37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# d:\project_tw\twedu\venv37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# d:\project_tw\twedu\venv37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
