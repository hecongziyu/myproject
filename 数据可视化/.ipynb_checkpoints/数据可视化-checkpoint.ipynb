# %% [raw]
# 1、https://www.jianshu.com/p/3bb2cc453df1   基于Python的数据可视化：从一维到多维

# %%
import networkx as nx
from pylab import *
from networkx.algorithms import approximation as approx
mpl.rcParams['font.sans-serif'] = ['SimHei'] 
# import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_node('中国')     # 添加节点z
G.add_nodes_from([1, 2, 3,4,5])   # 添加节点 1 2 3
G.add_edge('x', 'y', weight=15, label='123')          # 添加边  起点为x  终点为y
G.add_edges_from([(1, 2),(1,3),(2,3), (1,5),(5,4),(4,3),(1,4)],label="WN2898")   # 添加多条边

# 最短路径
print(nx.dijkstra_path(G, 1, 4))
print(G.has_edge(1,2))
# 寻找节点之间连接数
print(approx.node_connectivity(G,4,1))
# 网络图绘制与显示
nx.draw_circular(G, with_labels=True)
plt.show()
# Out:
# [1, 4]
# True
# 0

# %%
# ?nx.dijkstra_path

# %%
# https://algorithmx-python.readthedocs.io/en/latest/examples/networkx-examples.html
