# %% [markdown]
# # 说明

# %% [markdown]
# 一、off-policy（离线） vs on-policy（在线）
#     强化学习可以分成off-policy（离线）和on-policy（在线）两种学习方法，按照个人理解，判断一个强化学习是off-policy还是on-policy的依据在于生成样本的policy（value-funciton）和网络参数更新时的policy（value-funciton）是否相同。
#     Q-learning在计算下一状态的预期收益时使用了max操作，直接选择最优动作，而当前policy并不一定能选择到最优动作，因此这里生成样本的policy和学习时的policy不同，为off-policy算法；
#     而SARAS则是基于当前的policy直接执行一次动作选择，然后用这个样本更新当前的policy，因此生成样本的policy和学习时的policy相同，算法为on-policy算法。
#     on-policy 与 off-policy的本质区别在于：更新Q值时所使用的方法是沿用既定的策略（on-policy）还是使用新策略（off-policy）。

# %% [markdown]
# # Q_learning   (off-policy)

# %%
# from lib.maze.maze_env import Maze
# from lib.maze.RL_brain import QLearningTable
import lib.maze.maze_env as me
import lib.maze.Q_RL_brain as rl
import importlib
importlib.reload(me)
importlib.reload(rl)

def update():
    for episode in range(100):
        # initial observation
        observation = env.reset()

        while True:
            # fresh env
            env.render()
            # RL choose action based on observation
            action = RL.choose_action(str(observation))
            # RL take action and get next observation and reward
            observation_, reward, done = env.step(action)
            # RL learn from this transition
            RL.learn(str(observation), action, reward, str(observation_))
            # swap observation
            observation = observation_
            # break while loop when end of this episode
            if done:
                break

#         print(RL.q_table)
#         print('*' * 20)        

    # end of game
    print('game over')
    env.destroy()

env = me.Maze()
RL = rl.QLearningTable(actions=list(range(env.n_actions)))
env.after(1, update)
env.mainloop()
# Out:
# [5.0, 5.0, 35.0, 35.0]
# [5.0, 5.0, 35.0, 35.0]
# [5.0, 5.0, 35.0, 35.0]
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Python36\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "D:\Python36\lib\tkinter\__init__.py", line 745, in callit
#     func(*args)
#   File "<ipython-input-13-02554bf01632>", line 15, in update
#     observation_, reward, done = env.step(action)
#   File "D:\PROJECT_TW\git\myproject\game\lib\maze\maze_env.py", line 96, in step
#     s = self.canvas.coords(self.rect)
#   File "D:\Python36\lib\tkinter\__init__.py", line 2463, in coords
#     self.tk.call((self._w, 'coords') + args))]
# _tkinter.TclError: invalid command name ".!canvas"

# %% [markdown]
# # Sarsa  (on-policy)

# %%
import lib.maze.maze_env as me
import lib.maze.S_RL_brain as rl
import importlib
importlib.reload(me)
importlib.reload(rl)

def update():
    for episode in range(100):
        # initial observation
        observation = env.reset()

        # RL choose action based on observation
        action = RL.choose_action(str(observation))

        while True:
            # fresh env
            env.render()

            # RL take action and get next observation and reward
            observation_, reward, done = env.step(action)

            # RL choose action based on next observation
            action_ = RL.choose_action(str(observation_))

            # RL learn from this transition (s, a, r, s, a) ==> Sarsa
            RL.learn(str(observation), action, reward, str(observation_), action_)

            # swap observation and action
            observation = observation_
            action = action_

            # break while loop when end of this episode
            if done:
                break

    # end of game
    print('game over')
    env.destroy()

env = me.Maze()
RL = rl.SarsaTable(actions=list(range(env.n_actions)))
env.after(1, update)
env.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Python36\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "D:\Python36\lib\tkinter\__init__.py", line 745, in callit
#     func(*args)
#   File "<ipython-input-2-8ee6499b289e>", line 20, in update
#     observation_, reward, done = env.step(action)
#   File "D:\PROJECT_TW\git\myproject\game\lib\maze\maze_env.py", line 96, in step
#     s = self.canvas.coords(self.rect)
#   File "D:\Python36\lib\tkinter\__init__.py", line 2463, in coords
#     self.tk.call((self._w, 'coords') + args))]
# _tkinter.TclError: invalid command name ".!canvas"

# %% [markdown]
# # SarsaLambda (on-policy)

# %%
# 强化学习各种算法分析及Eligibility Trace教程  https://blog.csdn.net/weixin_37895339/article/details/74644038
# eligibility traces是一种将n步的信息备份起来的简洁方式

import lib.maze.maze_env as me
import lib.maze.S_LAMBDA_RL_brain as rl
import importlib
importlib.reload(me)
importlib.reload(rl)

def update():
    for episode in range(100):
        # initial observation
        observation = env.reset()

        # RL choose action based on observation
        action = RL.choose_action(str(observation))

        while True:
            # fresh env
            env.render()

            # RL take action and get next observation and reward
            observation_, reward, done = env.step(action)

            # RL choose action based on next observation
            action_ = RL.choose_action(str(observation_))

            # RL learn from this transition (s, a, r, s, a) ==> Sarsa
            RL.learn(str(observation), action, reward, str(observation_), action_)

            # swap observation and action
            observation = observation_
            action = action_

            # break while loop when end of this episode
            if done:
                break

    # end of game
    print('game over')
    env.destroy()

env = me.Maze()
RL = rl.SarsaLambdaTable(actions=list(range(env.n_actions)))
env.after(1, update)
env.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Python36\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "D:\Python36\lib\tkinter\__init__.py", line 745, in callit
#     func(*args)
#   File "<ipython-input-5-65bae49d0a23>", line 23, in update
#     observation_, reward, done = env.step(action)
#   File "D:\PROJECT_TW\git\myproject\game\lib\maze\maze_env.py", line 96, in step
#     s = self.canvas.coords(self.rect)
#   File "D:\Python36\lib\tkinter\__init__.py", line 2463, in coords
#     self.tk.call((self._w, 'coords') + args))]
# _tkinter.TclError: invalid command name ".!canvas"

# %% [markdown]
# # DQN

# %%
import lib.maze.maze_env as me
import lib.maze.DQN_RL_brain as rl
import importlib
importlib.reload(me)
importlib.reload(rl)

def update():
    step = 0
    for episode in range(1000):
        # initial observation
        observation = env.reset()

        # RL choose action based on observation
        

        while True:
            # fresh env
            env.render()
#             print('source --> {} type --> {}'.format(observation, type(observation)))
#             print('string source --> {}'.format(str(observation)))
            action = RL.choose_action(observation)
            
            # RL take action and get next observation and reward
            observation_, reward, done = env.step(action)

            if observation_ == 'terminal':
                observation_ = [0,0,0,0]
            
            RL.store_transition(observation,action,reward, observation_)
            
            if (step > 10) and (step % 5 == 0):
#                 print('rl begin learing ...')
                loss = RL.learn()
#                 print('action --> {}'.format(action))
#                 print('loss --> {}'.format(loss))
                
                
            # RL learn from this transition (s, a, r, s, a) ==> Sarsa
#             RL.learn(str(observation), action, reward, str(observation_), action_)

            # swap observation and action
            observation = observation_
 
            # break while loop when end of this episode
            if done:
                break
            step += 1

env = me.Maze()
RL = rl.DeepQNetwork()
env.after(10, update)
env.mainloop()
# Out:
# action --> 3
# loss --> 0.023900609463453293
# action --> 0
# loss --> 1.0836595296859741
# action --> 3
# loss --> 0.13768093287944794
# action --> 3
# loss --> 0.1649591475725174
# action --> 3
# loss --> 0.22429817914962769
# action --> 3
# loss --> 0.8412367701530457
# action --> 3
# loss --> 2.120361566543579
# action --> 3
# loss --> 0.4870727062225342
# action --> 3
# loss --> 0.13002225756645203
# action --> 2
# loss --> 0.2202146351337433
# action --> 2
# loss --> 6.087335586547852
# action --> 0
# loss --> 2.4260714054107666
# action --> 0
# loss --> 1.129141926765442
# action --> 0
# loss --> 0.7130463719367981
# action --> 3
# loss --> 0.013954575173556805
# action --> 3
# loss --> 0.18533633649349213
# action --> 3
# loss --> 1.143842101097107
# action --> 3
# loss --> 2.568225383758545
# action --> 3
# loss --> 5.533652305603027
# action --> 3
# loss --> 0.12222763150930405
# action --> 3
# loss --> 3.2625393867492676
# action --> 3
# loss --> 0.5973249673843384
# action --> 3
# loss --> 0.13336534798145294
# action --> 3
# loss --> 0.29880914092063904
# action --> 3
# loss --> 0.10680583119392395
# action --> 3
# loss --> 1.0838077068328857
# action --> 3
# loss --> 0.12058861553668976
# action --> 3
# loss --> 0.9744920134544373
# action --> 3
# loss --> 0.09203211218118668
# action --> 3
# loss --> 2.210373640060425
# action --> 3
# loss --> 0.5139492750167847
# action --> 3
# loss --> 0.04161781072616577
# action --> 3
# loss --> 1.0431020259857178
# action --> 3
# loss --> 1.894004225730896
# action --> 3
# loss --> 2.8258233070373535
# action --> 3
# loss --> 0.4482555091381073
# action --> 1
# loss --> 0.32504597306251526
# action --> 1
# loss --> 0.04445423185825348
# action --> 1
# loss --> 0.08732812106609344
# action --> 1
# loss --> 0.21852892637252808
# action --> 1
# loss --> 0.16043169796466827
# action --> 3
# loss --> 0.009842132218182087
# action --> 3
# loss --> 0.18503592908382416
# action --> 3
# loss --> 0.060639526695013046
# action --> 3
# loss --> 0.06084791198372841
# action --> 3
# loss --> 0.02686147205531597
# action --> 3
# loss --> 0.11907529085874557
# action --> 3
# loss --> 0.01669657789170742
# action --> 3
# loss --> 2.210559368133545
# action --> 0
# loss --> 4.727534294128418
# action --> 0
# loss --> 0.17729678750038147
# action --> 0
# loss --> 0.1321413815021515
# action --> 1
# loss --> 1.0575189590454102
# action --> 1
# loss --> 0.09444989264011383
# action --> 2
# loss --> 8.355998039245605
# action --> 2
# loss --> 0.2554251253604889
# action --> 1
# loss --> 0.032026030123233795
# action --> 1
# loss --> 0.4362029433250427
# action --> 1
# loss --> 0.10168097168207169
# action --> 1
# loss --> 0.5402904748916626
# action --> 1
# loss --> 0.2533787488937378
# action --> 2
# loss --> 0.11544592678546906
# action --> 3
# loss --> 0.08325747400522232
# action --> 3
# loss --> 0.7792331576347351
# action --> 3
# loss --> 0.45607954263687134
# action --> 3
# loss --> 0.03373967111110687
# action --> 3
# loss --> 0.5879215598106384
# action --> 3
# loss --> 0.407986581325531
# action --> 3
# loss --> 2.0850300788879395
# action --> 3
# loss --> 0.13220854103565216
# action --> 3
# loss --> 2.141167163848877
# action --> 3
# loss --> 0.07688930630683899
# action --> 3
# loss --> 0.40729883313179016
# action --> 3
# loss --> 0.2563267946243286
# action --> 0
# loss --> 0.12361150234937668
# action --> 1
# loss --> 0.2497466802597046
# action --> 3
# loss --> 0.4484199285507202
# action --> 1
# loss --> 0.3725581169128418
# action --> 1
# loss --> 0.05711741000413895
# action --> 1
# loss --> 1.0399526357650757
# action --> 1
# loss --> 0.5467789769172668
# action --> 1
# loss --> 0.43411117792129517
# action --> 2
# loss --> 0.1503724604845047
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Python36\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "D:\Python36\lib\tkinter\__init__.py", line 745, in callit
#     func(*args)
#   File "<ipython-input-2-c78c80a956c9>", line 18, in update
#     env.render()
#   File "D:\PROJECT_TW\git\myproject\game\lib\maze\maze_env.py", line 132, in render
#     time.sleep(0.1)
# KeyboardInterrupt
