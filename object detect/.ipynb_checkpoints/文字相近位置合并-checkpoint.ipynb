# %% [raw]
# https://github.com/eragonruan/text-detection-ctpn
#
# https://blog.csdn.net/bjbz_cxy/article/details/79741725  使用Opencv进行轮廓检测，字符提取，简单的直方图字符识别！

# %%
# 准备数据
import requests
import pickle

# url = 'http://127.0.0.1:16018/mlApi/ocr/general-text'
# files = {'image_file':open('D:\\img\\ocr\\2.jpg','rb')}

# response = requests.post(url, files=files)


# with open('d:\\img\\ocr\\2.data', 'wb') as fi:
#     pickle.dump(response,fi)
with open ('d:\\img\\ocr\\2.data','rb') as fi:
    rsp = pickle.load(fi)
data = eval(rsp.text)
words_block_list = data['words_block_list']

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import re
plt.rcParams['figure.figsize'] = 15, 10
image = cv2.imread('D:\\img\\ocr\\2.jpg')

def split_paragraph(words_block_list, paragraph_list):
    print(paragraph_list)
    words_block_array = np.array([x['location'] for x in words_block_list])
    
    paragraph_array  = np.array([x[0] for x in paragraph_list])
#     print(words_block_array[paragraph_array,0,0])
#     print('众数 --> ', np.median(words_block_array[paragraph_array,0,0]))
    paragraph_x_median = np.median(words_block_array[paragraph_array,0,0])
    paragraph_idx_filter = np.where(words_block_array[paragraph_array,0,0]/paragraph_x_median < 1.5)
    print('idx filter --> ', paragraph_idx_filter)
    paragraph_array = paragraph_array[paragraph_idx_filter]
    print('paragraph_array --> ', paragraph_array)
    
    
    print(words_block_array[paragraph_array,0,0] / np.median(words_block_array[paragraph_array,0,0]))
    paragraph_idx_list =zip(paragraph_array[:-1], paragraph_array[1:])
    words_position_list = [[np.min(words_block_array[x:y,:,0]),
                            np.min(words_block_array[x:y,:,1]),
                            np.max(words_block_array[x:y,:,0]),
                            np.max(words_block_array[x:y,:,1])] for x,y in paragraph_idx_list]
    
    return words_position_list

paragraph_list = []
for idx, item in enumerate(words_block_list):
    print('idx -->{} : {} --- {} '.format(idx,item['location'], item['words']))
    if re.search('^\d+\.', item['words']):
        paragraph_list.append([idx, item['words']])
#         print('idx -->{} : {} --- {} '.format(idx,item['location'], item['words']))
#         x,y,w,h = cv2.boundingRect(np.array(item['location']))
#         cv2.rectangle(image, (295,888),(2562,1027),0,-1)
#         cv2.rectangle(image, (x,y),(x+w, y+h),0,2)
paragraph_list.append([idx, item['words']])
words_position_list = split_paragraph(words_block_list, paragraph_list)
print(len(words_position_list))
for x1,y1,x2,y2 in words_position_list:
    cv2.rectangle(image, (x1,y1),(x2,y2),0,-1)
plt.imshow(image, 'brg')
plt.show()
# Out:
# idx -->0 : [[324, 256], [1016, 242], [1016, 304], [324, 317]] --- 课时代漂数学（江苏版）七年级上
# idx -->1 : [[1126, 417], [1733, 412], [1733, 472], [1126, 474]] --- 第4课时 数 轴（2）
# idx -->2 : [[306, 540], [540, 547], [538, 597], [306, 591]] --- 知识梳理
# idx -->3 : [[401, 653], [2555, 641], [2555, 714], [401, 725]] --- 在数轴上表示的两个数,右边的数总比左边的数大,(填"大"或*小").正数都_ 73 0,负数都以以才
# idx -->4 : [[295, 723], [1314, 727], [1314, 787], [295, 780]] --- 0,正数 人才 负数（填“大于”*小于”或“等于”）
# idx -->5 : [[298, 798], [531, 800], [531, 855], [298, 853]] --- 课堂作业
# idx -->6 : [[295, 913], [838, 917], [838, 959], [295, 955]] --- 1.（2017·丽水）在数1,0
# idx -->7 : [[919, 913], [1367, 908], [1367, 952], [919, 957]] --- 1,一2中,最大的数是
# idx -->8 : [[2489, 888], [2562, 888], [2562, 961], [2489, 961]] --- D
# idx -->9 : [[357, 985], [401, 985], [401, 1025], [357, 1025]] --- A.
# idx -->10 : [[485, 988], [507, 988], [507, 1023], [485, 1023]] --- 2
# idx -->11 : [[908, 990], [1047, 990], [1047, 1025], [908, 1027]] --- B. -1
# idx -->12 : [[1457, 988], [1556, 988], [1556, 1025], [1457, 1025]] --- C.0
# idx -->13 : [[2010, 985], [2103, 985], [2103, 1023], [2010, 1023]] --- D. 1
# idx -->14 : [[289, 1058], [1254, 1056], [1254, 1100], [289, 1104]] --- 2.（2017·鞍山）下列各数中，比一3小的数是
# idx -->15 : [[2478, 1047], [2564, 1047], [2564, 1115], [2478, 1115]] --- D
# idx -->16 : [[353, 1133], [397, 1133], [397, 1173], [353, 1173]] --- A.
# idx -->17 : [[478, 1133], [503, 1133], [503, 1168], [478, 1168]] --- 2
# idx -->18 : [[906, 1135], [1001, 1135], [1001, 1173], [906, 1173]] --- B.0
# idx -->19 : [[1457, 1135], [1550, 1135], [1550, 1173], [1457, 1173]] --- C. 1
# idx -->20 : [[2010, 1131], [2156, 1131], [2156, 1166], [2010, 1171]] --- D. .-4
# idx -->21 : [[284, 1199], [1413, 1204], [1413, 1250], [284, 1246]] --- 3.（1）写出所有比一5大的负整数：-4，3.-2.1
# idx -->22 : [[348, 1274], [2568, 1263], [2568, 1325], [348, 1336]] --- （2）若两个数同为负数，则较大的数所对应的点离原点较_近。；若两个数同为正数，则较大的数所对
# idx -->23 : [[434, 1349], [1327, 1351], [1327, 1406], [434, 1402]] --- 应的点离原点较_14.（填“近”或“远”）
# idx -->24 : [[276, 1424], [2570, 1417], [2570, 1453], [276, 1475]] --- 4.(2016·广东改编)数轴上点A,B 的位置如图所示,若点A,B 表示的数分别为a.b，则a__ 6
# idx -->25 : [[344, 1499], [780, 1495], [780, 1539], [344, 1543]] --- （填“>”*<”或“一”）
# idx -->26 : [[1221, 1600], [1246, 1600], [1246, 1636], [1221, 1636]] --- 4
# idx -->27 : [[1380, 1603], [1406, 1603], [1406, 1633], [1380, 1633]] --- B
# idx -->28 : [[1532, 1600], [1552, 1600], [1552, 1633], [1532, 1633]] --- 0
# idx -->29 : [[1362, 1647], [1484, 1647], [1484, 1684], [1362, 1684]] --- 第4题
# idx -->30 : [[267, 1713], [851, 1713], [851, 1757], [267, 1757]] --- 5. 用*>”*<”或*-- 填空：
# idx -->31 : [[1188, 1768], [1210, 1768], [1210, 1805], [1188, 1805]] --- 3
# idx -->32 : [[1486, 1766], [1506, 1766], [1506, 1803], [1486, 1803]] --- 2
# idx -->33 : [[333, 1799], [747, 1797], [747, 1836], [333, 1839]] --- （1）（2017.玉林）0
# idx -->34 : [[840, 1792], [1413, 1790], [1415, 1858], [840, 1841]] --- 2--3;(2)2-7
# idx -->35 : [[1821, 1772], [2555, 1772], [2555, 1839], [1821, 1839]] --- （3）（2016·台州）-2_2 2-3；
# idx -->36 : [[1484, 1814], [1536, 1814], [1536, 1865], [1484, 1865]] --- 3
# idx -->37 : [[842, 1907], [860, 1907], [860, 1944], [842, 1944]] --- 1
# idx -->38 : [[331, 1940], [677, 1936], [677, 1973], [331, 1977]] --- （4）-0.25 2
# idx -->39 : [[1085, 1927], [1453, 1927], [1453, 1973], [1085, 1973]] --- （5）一1000 ∠
# idx -->40 : [[1585, 1936], [1673, 1936], [1673, 1975], [1585, 1975]] --- 100；
# idx -->41 : [[1821, 1918], [2350, 1929], [2350, 1969], [1821, 1971]] --- （6）-π < -3.14.
# idx -->42 : [[838, 1953], [895, 1953], [895, 2006], [838, 2006]] --- 4
# idx -->43 : [[258, 2041], [1825, 2030], [1825, 2079], [258, 2088]] --- 6. 在数轴上画出表示下列各数的点,并将它们按照从小到大的顺序排列：
# idx -->44 : [[1142, 2116], [1164, 2116], [1164, 2154], [1142, 2154]] --- 5
# idx -->45 : [[1466, 2114], [1488, 2114], [1488, 2152], [1466, 2152]] --- 3
# idx -->46 : [[1254, 2149], [1398, 2149], [1398, 2187], [1254, 2187]] --- 3,0.4,
# idx -->47 : [[1532, 2145], [1761, 2143], [1761, 2180], [1532, 2182]] --- 1.5,一2.5
# idx -->48 : [[1142, 2171], [1197, 2171], [1197, 2218], [1142, 2218]] --- 2 '
# idx -->49 : [[1466, 2176], [1488, 2176], [1488, 2213], [1466, 2213]] --- 2
# idx -->50 : [[1682, 2328], [1704, 2328], [1704, 2374], [1682, 2374]] --- 5
# idx -->51 : [[2407, 2339], [2467, 2339], [2467, 2368], [2407, 2368]] --- 1.4
# idx -->52 : [[1234, 2365], [1259, 2365], [1259, 2409], [1234, 2409]] --- 3
# idx -->53 : [[1667, 2381], [1695, 2381], [1695, 2392], [1667, 2392]] --- 税 额
# idx -->54 : [[977, 2403], [1168, 2403], [1168, 2445], [977, 2445]] --- -3.2.5
# idx -->55 : [[1237, 2414], [1257, 2414], [1257, 2436], [1237, 2436]] --- 2
# idx -->56 : [[1426, 2396], [1490, 2396], [1490, 2429], [1426, 2429]] --- 0.件
# idx -->57 : [[1536, 2403], [1583, 2403], [1583, 2436], [1536, 2436]] --- 14
# idx -->58 : [[961, 2449], [1182, 2449], [1182, 2489], [961, 2489]] --- _
# idx -->59 : [[1446, 2456], [1521, 2456], [1521, 2467], [1446, 2467]] --- 税额
# idx -->60 : [[1592, 2443], [1830, 2443], [1830, 2476], [1592, 2476]] --- 瑞安市飞云镇佳达
# idx -->61 : [[1389, 2498], [1415, 2498], [1415, 2524], [1389, 2524]] --- 0
# idx -->62 : [[1611, 2489], [1640, 2489], [1640, 2515], [1611, 2515]] --- 2
# idx -->63 : [[1726, 2480], [1746, 2480], [1746, 2522], [1726, 2522]] --- 5
# idx -->64 : [[974, 2511], [1290, 2511], [1290, 2566], [974, 2566]] --- -3 - - -
# idx -->65 : [[1894, 2531], [1931, 2531], [1931, 2581], [1894, 2581]] --- 5
# idx -->66 : [[919, 2575], [1900, 2537], [1905, 2623], [921, 2661]] --- -3 2 -25 < $ 20* 2/< < ?
# idx -->67 : [[245, 2731], [478, 2731], [478, 2789], [245, 2789]] --- 课后作业
# idx -->68 : [[238, 2877], [1517, 2868], [1517, 2925], [238, 2934]] --- 7.(2016·重庆)在1,0,一1,一一这四个数中,最小的数是
# idx -->69 : [[2436, 2861], [2579, 2861], [2579, 2919], [2436, 2919]] --- （D）
# idx -->70 : [[1592, 2980], [1605, 2980], [1605, 3020], [1592, 3020]] --- 1
# idx -->71 : [[2015, 3007], [2160, 3007], [2160, 3044], [2015, 3047]] --- D. -1
# idx -->72 : [[304, 3029], [403, 3029], [403, 3071], [304, 3071]] --- A.1
# idx -->73 : [[873, 3031], [972, 3031], [972, 3071], [873, 3071]] --- B.0
# idx -->74 : [[1446, 3018], [1490, 3018], [1490, 3060], [1446, 3060]] --- C.
# idx -->75 : [[1587, 3044], [1609, 3044], [1609, 3084], [1587, 3084]] --- 2
# idx -->76 : [[2436, 3110], [2577, 3110], [2577, 3163], [2436, 3163]] --- （D）
# idx -->77 : [[231, 3141], [1285, 3126], [1285, 3177], [231, 3192]] --- 8.（2017·内江）下列四个数中，比一5 小的数是
# idx -->78 : [[298, 3221], [399, 3221], [399, 3260], [298, 3260]] --- A.1
# idx -->79 : [[871, 3218], [970, 3218], [970, 3260], [871, 3260]] --- B.0
# idx -->80 : [[1446, 3203], [1596, 3203], [1596, 3238], [1446, 3243]] --- C. -4
# idx -->81 : [[2015, 3192], [2165, 3192], [2165, 3230], [2015, 3232]] --- D.-6
# idx -->82 : [[227, 3296], [877, 3293], [877, 3340], [227, 3344]] --- 9.比较大小（填“>”或*<”）：
# idx -->83 : [[1607, 3353], [1622, 3353], [1622, 3390], [1607, 3390]] --- 1
# idx -->84 : [[1715, 3322], [1788, 3322], [1788, 3399], [1715, 3399]] --- <
# idx -->85 : [[295, 3397], [1076, 3379], [1076, 3459], [295, 3476]] --- （1）（2016·黔南州）3_）>--5；
# idx -->86 : [[1448, 3388], [1514, 3388], [1514, 3430], [1448, 3430]] --- （2）
# idx -->87 : [[1845, 3384], [1889, 3384], [1889, 3426], [1845, 3426]] --- 0；
# idx -->88 : [[1603, 3417], [1625, 3417], [1625, 3454], [1603, 3454]] --- 4
# idx -->89 : [[1605, 3492], [1622, 3492], [1622, 3532], [1605, 3532]] --- 1
# idx -->90 : [[1913, 3492], [1929, 3492], [1929, 3529], [1913, 3529]] --- 1
# idx -->91 : [[1446, 3529], [1514, 3529], [1514, 3571], [1446, 3571]] --- （4）
# idx -->92 : [[1603, 3496], [1841, 3496], [1841, 3595], [1603, 3595]] --- 2/
# idx -->93 : [[291, 3551], [866, 3560], [866, 3626], [291, 3615]] --- （3）-3.2_22-4.3g
# idx -->94 : [[1911, 3558], [1931, 3558], [1931, 3595], [1911, 3595]] --- 3
# idx -->95 : [[258, 3730], [306, 3730], [306, 3774], [258, 3774]] --- 14
# [[6, '1.（2017·丽水）在数1,0'], [14, '2.（2017·鞍山）下列各数中，比一3小的数是'], [21, '3.（1）写出所有比一5大的负整数：-4，3.-2.1'], [24, '4.(2016·广东改编)数轴上点A,B 的位置如图所示,若点A,B 表示的数分别为a.b，则a__ 6'], [30, '5. 用*>”*<”或*-- 填空：'], [43, '6. 在数轴上画出表示下列各数的点,并将它们按照从小到大的顺序排列：'], [47, '1.5,一2.5'], [51, '1.4'], [56, '0.件'], [68, '7.(2016·重庆)在1,0,一1,一一这四个数中,最小的数是'], [77, '8.（2017·内江）下列四个数中，比一5 小的数是'], [82, '9.比较大小（填“>”或*<”）：'], [95, '14']]
# idx filter -->  (array([ 0,  1,  2,  3,  4,  5,  9, 10, 11, 12], dtype=int64),)
# paragraph_array -->  [ 6 14 21 24 30 43 68 77 82 95]
# [1.12380952 1.10095238 1.08190476 1.05142857 1.01714286 0.98285714
#  0.90666667 0.88       0.8647619  0.98285714]
# 9

# %%
words_block_array = np.array([x['location'] for x in words_block_list])
paragraph_array  = np.array([x[0] for x in paragraph_list])
print(words_block_array.shape)
print(paragraph_array)
x = words_block_array[6:14,]
print(np.min(x[:,:,0]),np.min(x[:,:,1]),np.max(x[:,:,0]),np.max(x[:,:,1]))
# Out:
# (96, 4, 2)
# [ 6 14 21 24 30 43 47 51 56 68 77 82]
# 295 888 2562 1027
