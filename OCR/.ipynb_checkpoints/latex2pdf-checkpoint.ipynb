# %% [raw]
# 1、https://miktex.org/download 安装 miktex
# 2、https://python.hotexamples.com/examples/pylatex/Document/generate_pdf/python-document-generate_pdf-method-examples.html
# 3、https://blog.csdn.net/xiazhaoqiang/article/details/7691268?utm_medium=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-3.nonecase&depth_1-utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-3.nonecase 安装Latex包
# 4、www.ctan.org/tex-archive/macros/latex/contrib/mdframed MDFramed说明
# 5、http://ctan.mirror.rafal.ca/macros/latex/contrib/tcolorbox/tcolorbox.pdf
# 6、https://blog.csdn.net/suifenghahahaha/article/details/79075069 字体颜色设置
# 7、https://www.cnblogs.com/pythonClub/p/10491988.html python opencv 检测特定颜色
# 8、https://blog.csdn.net/wx19900503/article/details/92645553
# 9、https://blog.csdn.net/WZZ18191171661/article/details/90771800
# 10、https://blog.csdn.net/hfutdog/article/details/82146089 ！！！

# %% [markdown]
# # 方案一

# %%
from pylatex.base_classes import Environment,Arguments,CommandBase
from pylatex import Document, Section, Subsection, Command,Alignat,Matrix,UnsafeCommand
from pylatex.package import Package
from pylatex.utils import italic, NoEscape
import sys

M = np.matrix([[2, 3, 4],
               [0, 0, 1],
               [0, 0, 2]])

class ExampleEnvironment(Environment):
    """
    A class representing a custom LaTeX environment.

    This class represents a custom LaTeX environment named
    ``exampleEnvironment``.
    """

    _latex_name = 'exampleEnvironment'
    escape = False
    packages = [Package('tcolorbox'),Package('amsmath')]
    
class ExampleCommand(CommandBase):
    """
    A class representing a custom LaTeX command.

    This class represents a custom LaTeX command named
    ``exampleCommand``.
    """

    _latex_name = 'exampleCommand'
    packages = [Package('color')]
    
    
# reload(sys)
# sys.setdefaultencoding('utf-8')
class AllTT(Environment):
    """A class to wrap LaTeX's alltt environment."""

    packages = [Package('alltt')]
    escape = False
    content_separator = "\n"
    
def fill_document(doc):
    """Add a section, a subsection and some text to the document.

    :param doc: the document
    :type doc: :class:`pylatex.document.Document` instance
    """
    with doc.create(Section('A section')):
        doc.append('Some regular text and some ')
        doc.append(italic('italic text. '))

        with doc.create(Subsection('A subsection')):
            doc.append('Also some crazy characters: $&#{}')


if __name__ == '__main__':
    
#     geometry_options = {
#         "includeheadfoot": True,
#         "headheight": "12pt",
#         "headsep": "10pt",
#         "landscape": True
#     }    
    geometry_options = {"tmargin": "1cm", "lmargin": "1cm"}
    doc = Document(geometry_options=geometry_options)
    # Basic document

    doc.packages.add(Package('ctex'))
    doc.preamble.append(Command('title', '123'))
#     # Add stuff to the document
    with doc.create(Section('123')):
        doc.append('测试')
        doc.append('12344')
        with doc.create(Alignat(numbering=False, escape=False)) as agn:
            agn.append(r'\frac{a}{b} &= 0 \\')
            
        with doc.create(Subsection('Alignat math environment')):
            with doc.create(Alignat(numbering=False, escape=False)) as agn:
                doc.append('test:')
                agn.append(r'\frac{a}{b} &= 0 \\')
#                 agn.extend([Matrix(M), Matrix(a), '&=', Matrix(M * a)])


    with doc.create(Section('Custom environments')):
        doc.append(NoEscape(
            r"""
            The following is a demonstration of a custom \LaTeX{}
            environment using the mdframed package.
            """))        

        # Define a style for our box
#         mdf_style_definition = UnsafeCommand('mdfdefinestyle',
#                                              arguments=['my_style',
#                                                         ('linecolor=#1,'
#                                                          'linewidth=#2,'
#                                                         'align=center,'
#                                                          'leftmargin=1cm,'
#                                                          'leftmargin=1cm')])

#         mdf_style_definition = UnsafeCommand('mdfdefinestyle',
#                                              arguments=['style',
#                                                         ()])

        # Define the new environment using the style definition above
#         new_env = UnsafeCommand('newenvironment', 'exampleEnvironment', options=2,
#                                 extra_arguments=[
#                                     mdf_style_definition.dumps() +
#                                     r'\begin{mdframed}[style=my_style]',
#                                     r'\end{mdframed}'])

        new_env = UnsafeCommand('newenvironment', 'exampleEnvironment', options=0,
                                extra_arguments=[
                                    r'\begin{tcolorbox}',
                                    r'\end{tcolorbox}'])
        doc.append(new_env)        
        
#         with doc.create(ExampleEnvironment(arguments=Arguments('red', 1))) as environment:
        with doc.create(ExampleEnvironment()) as environment:
#             with doc.create(Alignat(numbering=False, escape=False)) as agn:
            environment.append(r'Text\tcbox[tcbox raise base]{$g(x) &= \frac{1}{x}\\$}\hfil')
#             environment.append(NoEscape(r'Text\tcbox[tcbox raise base]{$g(x) &= \frac{1}{x}\\$}\hfil'))
#             environment.append(r'Text\tcbox[tcbox raise base]{$g(x) &=  \frac{1}{x}\\$}\hfil')
            doc.append(r'This formula $f(x) = x^2$ is an example')
        
#             environment.append(r'\frac{a}{b} &= 0 \\')
        
    doc.generate_pdf('basic_maketitle', clean_tex=True,compiler='xelatex')
#     tex = doc.dumps()  # The document as string in LaTeX syntax
    
    print('over')
# Out:
# xelatex: security risk: running with elevated privileges
# This is XeTeX, Version 3.14159265-2.6-0.999992 (MiKTeX 2.9.7400 64-bit)
# entering extended mode
# (basic_maketitle.tex
# LaTeX2e <2020-02-02> patch level 5
# L3 programming layer <2020-04-06>
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\article.cls"
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\size10.clo"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\fontenc.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/lm\t1lmr.fd"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\inputenc.sty"
#
# Package inputenc Warning: inputenc package ignored with utf8 based engines.
#
# ) ("E:\Program Files\MiKTeX 2.9\tex/latex/lm\lmodern.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\textcomp.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/lastpage\lastpage.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/geometry\geometry.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics\keyval.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/iftex\ifvtex.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/iftex\iftex.sty"))
# ("E:\Program Files\MiKTeX 2.9\tex/xelatex/xetexconfig\geometry.cfg"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex\ctex.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/l3kernel\expl3.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/l3backend\l3backend-xdvipdfmx.def"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/l3packages/xparse\xparse.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/l3packages/l3keys2e\l3keys2e.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex\ctexhook.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex\ctexpatch.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\fix-cm.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\ts1enc.def"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ms\everysel.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex/config\ctexopts.cfg")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex/engine\ctex-engine-xetex.def"
# ("E:\Program Files\MiKTeX 2.9\tex/xelatex/xecjk\xeCJK.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/l3packages/xtemplate\xtemplate.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/fontspec\fontspec.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/fontspec\fontspec-xetex.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/base\fontenc.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/fontspec\fontspec.cfg")))
# ("E:\Program Files\MiKTeX 2.9\tex/xelatex/xecjk\xeCJK.cfg")))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/zhnumber\zhnumber.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/zhnumber\zhnumber-utf8.cfg"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex/scheme\ctex-scheme-chinese.def"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex/config\ctex-name-utf8.cfg"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/tools\indentfirst.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex\ctex-c5size.clo")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex/fontset\ctex-fontset-windows.def")
# ) ("E:\Program Files\MiKTeX 2.9\tex/latex/ctex/config\ctex.cfg")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/amsmath\amsmath.sty"
# For additional information on amsmath, use the `?' option.
# ("E:\Program Files\MiKTeX 2.9\tex/latex/amsmath\amstext.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/amsmath\amsgen.sty"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/amsmath\amsbsy.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/amsmath\amsopn.sty"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/tcolorbox\tcolorbox.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/pgf/basiclayer\pgf.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/pgf/utilities\pgfrcs.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/utilities\pgfutil-common.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/utilities\pgfutil-common-lists.te
# x")) ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/utilities\pgfutil-latex.def"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/ms\everyshi.sty"))
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/utilities\pgfrcs.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf\pgf.revision.tex")))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/pgf/basiclayer\pgfcore.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics\graphicx.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics\graphics.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics\trig.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics-cfg\graphics.cfg")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics-def\xetex.def")))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/pgf/systemlayer\pgfsys.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgfsys.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/utilities\pgfkeys.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/utilities\pgfkeysfiltered.code.te
# x")) ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgf.cfg")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgfsys-xetex.def"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgfsys-dvipdfmx.def"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgfsys-common-pdf.def
# "))))
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgfsyssoftpath.code.t
# ex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/systemlayer\pgfsysprotocol.code.t
# ex")) ("E:\Program Files\MiKTeX 2.9\tex/latex/xcolor\xcolor.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/graphics-cfg\color.cfg"))
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcore.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmath.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathcalc.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathutil.code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathparser.code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.code.tex"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.basic.code.
# tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.trigonometr
# ic.code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.random.code
# .tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.comparison.
# code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.base.code.t
# ex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.round.code.
# tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.misc.code.t
# ex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfunctions.integerarit
# hmetics.code.tex")))
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfmathfloat.code.tex"))
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/math\pgfint.code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorepoints.code.tex
# ")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorepathconstruct.c
# ode.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorepathusage.code.
# tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorescopes.code.tex
# ")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoregraphicstate.co
# de.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoretransformations
# .code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorequick.code.tex"
# )
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoreobjects.code.te
# x")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorepathprocessing.
# code.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorearrows.code.tex
# ")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoreshade.code.tex"
# ) ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoreimage.code.te
# x"
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoreexternal.code.t
# ex"))
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorelayers.code.tex
# ")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcoretransparency.co
# de.tex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorepatterns.code.t
# ex")
# ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/basiclayer\pgfcorerdf.code.tex"))
# ) ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/modules\pgfmoduleshapes.code.te
# x") ("E:\Program Files\MiKTeX 2.9\tex/generic/pgf/modules\pgfmoduleplot.code.te
# x")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/pgf/compatibility\pgfcomp-version-0-65.
# sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/pgf/compatibility\pgfcomp-version-1-18.
# sty")) ("E:\Program Files\MiKTeX 2.9\tex/latex/tools\verbatim.sty")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/environ\environ.sty"
# ("E:\Program Files\MiKTeX 2.9\tex/latex/trimspaces\trimspaces.sty"))
# ("E:\Program Files\MiKTeX 2.9\tex/latex/etoolbox\etoolbox.sty"))
# (basic_maketitle.aux)
# *geometry* detected driver: pdftex
# ABD: EverySelectfont initializing macros ABD: EveryShipout initializing macros
# ("E:\Program Files\MiKTeX 2.9\tex/latex/lm\ot1lmr.fd")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/lm\omllmm.fd")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/lm\omslmsy.fd")
# ("E:\Program Files\MiKTeX 2.9\tex/latex/lm\omxlmex.fd")
# ! Missing } inserted.
# <inserted text>
#                 }
# l.40 ...x[tcbox raise base]{g(x) &= \frac{1}{x}\\}
#                                                   \hfil
# ! Missing } inserted.
# <inserted text>
#                 }
# l.40 ...x[tcbox raise base]{g(x) &= \frac{1}{x}\\}
#                                                   \hfil
# ! Extra }, or forgotten \endgroup.
# <inserted text> }
#
# l.40 ...x[tcbox raise base]{g(x) &= \frac{1}{x}\\}
#                                                   \hfil
# ! Missing } inserted.
# <inserted text>
#                 }
# l.40 ...x[tcbox raise base]{g(x) &= \frac{1}{x}\\}
#                                                   \hfil
# ! Extra }, or forgotten \endgroup.
# <inserted text> }
#
# l.40 ...x[tcbox raise base]{g(x) &= \frac{1}{x}\\}
#                                                   \hfil
# ! Missi
# <b>limit_output extension: Maximum message size of 10000 exceeded with 26816 characters</b>
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-70-5a67fe7a27d9> in <module>
#     130 #             environment.append(r'\frac{a}{b} &= 0 \\')
#     131
# --> 132     doc.generate_pdf('basic_maketitle', clean_tex=True,compiler='xelatex')
#     133 #     tex = doc.dumps()  # The document as string in LaTeX syntax
#     134
#
# d:\project_tw\twedu\venv37\lib\site-packages\pylatex\document.py in generate_pdf(self, filepath, clean, clean_tex, compiler, compiler_args, silent)
#     231             try:
#     232                 output = subprocess.check_output(command,
# --> 233                                                  stderr=subprocess.STDOUT)
#     234             except (OSError, IOError) as e:
#     235                 # Use FileNotFoundError when python 2 is dropped
#
# d:\tools\python37\Lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     393
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#     397
#
# d:\tools\python37\Lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     485         if check and retcode:
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#     489
#
# CalledProcessError: Command '['xelatex', '--interaction=nonstopmode', 'basic_maketitle.tex']' returned non-zero exit status 1.

# %% [markdown]
# # 方案二

# %% [markdown]
# ## 生成带底色的PDF文件

# %%
from pylatex.base_classes import Environment, CommandBase, Arguments
from pylatex.package import Package
from pylatex import Document, Section, UnsafeCommand
from pylatex.utils import NoEscape


# Create a new document
doc = Document()
doc.packages.add(Package('ctex'))
doc.packages.add(Package('color'))
doc.packages.add(Package('xcolor'))
# with doc.create(Section('Custom commands')):
#     doc.append(NoEscape(
#         r"""
#         The following is a demonstration of a custom \LaTeX{}
#         command with a couple of parameters.
#         """))

with doc.create(Section('Custom environments')):
    doc.append(NoEscape(
        r"""
        一、选择题
            1．下列关于金属利用的说法错误的是 （ ）
                A．用铝制高压电线 \colorbox{red}{$f(x) = x^2$}
                B．用钨制灯丝
                C．用纯铁制机床底座 \colorbox{red}{$\frac{9}{3}+{2}$}
                D．用铝粉制防锈漆
            2．下列物质不属于合金的是 （ ） A．青铜 B．铝 C．钢 D．生铁
            3．在金属表面覆盖保护膜是普遍采用的金属防锈措施之一。下列自行车的防锈措施中，不属于覆盖保护膜的是 （ ） 
                A．擦拭保持洁净与干燥       B．链条上油   C．轮圈镀铬 D．车架喷漆 4．早在春秋战国时期，我国就开始生产和
        """))
    
    doc.append(NoEscape(
        r"""
        \textcolor{black}{测试试题} \colorbox{red}{is} \textcolor{black}{a demonstration of a custom} \colorbox{red}{$f(x) = x^2$}
        environment using the mdframed package.\colorbox{red}{$\frac{9}{3}+{2}$}
        """))    
     

doc.generate_pdf('own_commands_ex',clean_tex=True,compiler='xelatex')
print('gen over')
# Out:
# gen over

# %% [markdown]
# ## 解析PDF文件，读取带底色文字位置

# %%
from lib.im2latex.pdfutils import pdf_convert_image
import cv2
import numpy as np
from matplotlib import pyplot as plt 
fig = plt.figure(figsize=(12,10))
pdf_file = 'own_commands_ex.pdf'
with open(pdf_file, 'rb') as f:
    data=f.read()
image, words = pdf_convert_image(data)
image = cv2.imdecode(np.frombuffer(image, np.uint8),cv2.IMREAD_COLOR)
boundaries = [[0, 0, 255], [0, 0, 255]] # 红色
lower = np.array(boundaries[0], dtype="uint8")
upper = np.array(boundaries[1], dtype="uint8")
mask = cv2.inRange(image, lower, upper)
output = cv2.bitwise_and(image, image, mask=mask)
gray = cv2.cvtColor(output, cv2.COLOR_BGR2GRAY)
ret, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
for cnt in contours:
    print(cv2.contourArea(cnt))
    x,y,w,h = cv2.boundingRect(cnt)
    print(x,y,w,h)
    cv2.rectangle(image,(x,y),(x+w,y+h),0,-1)
# print(mask)
# print(len(np.where(image==0)[0]))
# image[np.where(image==0)[0]] = 255
# 图片灰度、二值化
# image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
# image[np.where(image==0)[0]] = 255
# print(len(np.where(image==0)[0]))
plt.imshow(image)
plt.show()
# Out:
# 448.0
# 269 169 29 17
# 121.0
# 204 153 12 12
# 735.0
# 365 151 50 16
